# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolo11n.pt')
model = YOLO('yolo11n.yaml')

# %% [markdown]
# ## Chú thích các nhãn
#
# #### 3: Bệnh bọ xít; 0: Bệnh đốm nâu; 1: Bệnh đốm xám; 2: Bệnh nhện đỏ; 4: Lá khỏe

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/drive/MyDrive/yolo11_kltn_25_11

# %%
# !unzip -q data_noheath.zip

# %%
results = model.train(
    data='data.yaml',
    epochs=200,
    imgsz=640,
    flipud=0.0,
    fliplr=0.0,
    hsv_h=0.0,
    hsv_s=0.0,
    hsv_v=0.0,
    lr0=0.001,
    lrf=0.1,
    weight_decay=0.0005

,
    project='/content/drive/MyDrive/yolo11_kltn_25_11',
    name='yolo11n_no_aug_overfit_fix_1'
)# thêm regularization
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
